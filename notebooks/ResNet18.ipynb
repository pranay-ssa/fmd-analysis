# %%
pip install -U keras keras-hub
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.13/dist-packages (3.13.2)
# Collecting keras
#   Downloading keras-3.15.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: keras-hub in /usr/local/lib/python3.13/dist-packages (0.26.0)
# Collecting keras-hub
#   Downloading keras_hub-0.31.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.13/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from keras) (2.1.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.13/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.13/dist-packages (from keras) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.13/dist-packages (from keras) (0.20.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.13/dist-packages (from keras) (0.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from keras) (26.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from keras-hub) (2025.11.3)
# Requirement already satisfied: kagglehub!=1.0.1 in /usr/local/lib/python3.13/dist-packages (from keras-hub) (1.0.2)
# Collecting kagglesdk==0.1.28 (from keras-hub)
#   Downloading kagglesdk-0.1.28-py3-none-any.whl.metadata (13 kB)
# Collecting sentencepiece<0.2.2 (from keras-hub)
#   Downloading sentencepiece-0.2.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.13/dist-packages (from keras-hub) (0.23.1)
# Requirement already satisfied: tensorflow-text<2.21.0,>=2.20.1 in /usr/local/lib/python3.13/dist-packages (from keras-hub) (2.20.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.13/dist-packages (from kagglesdk==0.1.28->keras-hub) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from kagglesdk==0.1.28->keras-hub) (2.32.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from kagglehub!=1.0.1->keras-hub) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from kagglehub!=1.0.1->keras-hub) (4.67.3)
# Requirement already satisfied: tensorflow<2.21,>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow-text<2.21.0,>=2.20.1->keras-hub) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from optree->keras) (4.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras) (2.21.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers->keras-hub) (1.28.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (0.28.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (2.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (1.83.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->kagglesdk==0.1.28->keras-hub) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->kagglesdk==0.1.28->keras-hub) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->kagglesdk==0.1.28->keras-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->kagglesdk==0.1.28->keras-hub) (2026.7.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (0.48.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->keras-hub) (0.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (3.10.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text<2.21.0,>=2.20.1->keras-hub) (3.0.3)
# Downloading keras-3.15.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 90.1 MB/s eta 0:00:00
# Downloading keras_hub-0.31.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.5 MB/s eta 0:00:00
# Downloading kagglesdk-0.1.28-py3-none-any.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 kB 29.8 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 101.4 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, kagglesdk, keras, keras-hub
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.2
#     Uninstalling sentencepiece-0.2.2:
#       Successfully uninstalled sentencepiece-0.2.2
#   Attempting uninstall: kagglesdk
#     Found existing installation: kagglesdk 0.1.37
#     Uninstalling kagglesdk-0.1.37:
#       Successfully uninstalled kagglesdk-0.1.37
#   Attempting uninstall: keras
#     Found existing installation: keras 3.13.2
#     Uninstalling keras-3.13.2:
#       Successfully uninstalled keras-3.13.2
#   Attempting uninstall: keras-hub
#     Found existing installation: keras-hub 0.26.0
#     Uninstalling keras-hub-0.26.0:
#       Successfully uninstalled keras-hub-0.26.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.31.1 which is incompatible.
# Successfully installed kagglesdk-0.1.28 keras-3.15.1 keras-hub-0.31.1 sentencepiece-0.2.1

# %%
import tensorflow as tf
import keras
import keras_hub

inputs = keras.Input(shape=(224, 224, 3))

# Load ResNet18 with ImageNet pretrained weights
base_model = keras_hub.models.ResNetBackbone.from_preset(
    "resnet_18_imagenet",
    load_weights=True
)

# Fine-tuning enabled
base_model.trainable = True

# Pass input through pretrained ResNet18
x = base_model(inputs)

x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(1024, activation=None)(x)
x = keras.layers.Dropout(0.3)(x)

outputs = keras.layers.Dense(
    num_classes,
    activation="softmax"
)(x)

model = keras.Model(inputs, outputs)
